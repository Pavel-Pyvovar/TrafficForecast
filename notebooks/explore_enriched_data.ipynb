# %%
import pandas as pd

# %%
df = pd.read_parquet("../data/london/road_graph_edges_enriched.parquet")

# %%
df.head()
# Out:
#        u                    v  parsed_maxspeed  speed_kph  importance  \
# 0  78112             25508583             32.2       32.2           0
# 1  78112             25508584             32.2       32.2           0
# 2  78112  3257621681005534125             32.2       32.2           0
# 3  99936           2146383887             32.2       32.2           0
# 4  99936           4544836433             32.2       32.2           0
#
#         highway  oneway  length_meters  counter_distance  num_lanes  ...  \
# 0  unclassified   False      19.402386                 6          1  ...
# 1  unclassified   False      63.881347                 4          1  ...
# 2   residential    True      82.385612                 5          1  ...
# 3  unclassified   False       8.076410                 1          1  ...
# 4  unclassified    True      46.803240                 0          1  ...
#
#     leisure  shopping   tourism   traffic  transport  pois_total  greeneries  \
# ...

# %%
df.columns
# Out:
# Index(['u', 'v', 'parsed_maxspeed', 'speed_kph', 'importance', 'highway',
#        'oneway', 'length_meters', 'counter_distance', 'num_lanes', 'mean_pop',
#        'catering', 'leisure', 'shopping', 'tourism', 'traffic', 'transport',
#        'pois_total', 'greeneries', 'water_bodies', 'built_up', 'other'],
#       dtype='object')
